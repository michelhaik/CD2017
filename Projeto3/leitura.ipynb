# %% [markdown]
# # Projeto 3 Ciência dos dados
#   ### Michel Haikewitsch, Tiago Mingossi e Pedro Maciel
#   #### Tema: CartolaFC

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
print('Esperamos trabalhar no diretório')
print(os.getcwd())
# Out:
# Esperamos trabalhar no diretório
# C:\Users\haik_000\Desktop\insper\meu\CD2017\Projeto3

# %%
dados=pd.read_csv('db/2016/scouts.csv',sep=',')

atletas=pd.read_csv('db/2016/Atletas.csv',sep=',')
clubes=pd.read_csv('db/2016/Clubes.csv',sep=',')
jogos= pd.read_csv('db/2016/matches-brasileirao-2016.csv',sep=',')
partidas=pd.read_csv('db/2016/Partidas.csv',sep=',')
posicoes=pd.read_csv('db/2016/Posicoes.csv',sep=',')
status=pd.read_csv('db/2016/Status.csv',sep=',')
#dados=dados[dados.Participou==True]
atletas=atletas.rename(columns={'ID': "AtletaID"})
clubes=clubes.rename(columns={'ID': "ClubeID"})

dados= pd.merge(dados,atletas[['AtletaID', 'PosicaoID', 'Apelido']], on='AtletaID')
dados=pd.merge(dados,clubes[['ClubeID', 'Abreviacao']], on ="ClubeID")

# %%
#df = df.drop('column_name', 1)
dados=dados
#dados=dados.drop(('ClubeID') and ('AtletaID'),1)
#dados=dados.drop('AtletaID',1)
dados
columns = ['ClubeID', 'AtletaID'] #, ...]
#dados=dados.drop(['ClubeID', 'AtletaID'], axis=1)
dados=dados.rename(columns={'Abreviacao': 'Sigla'})
dados=dados.rename(columns={'Apelido': 'Atleta'})
#
dados
# Out:
#        Rodada ClubeID  AtletaID  Participou  Pontos  PontosMedia  Preco  \
# 0           0     294     37623       False     0.0         0.00   4.00
# 1           1     294     37623        True     5.3         5.30   6.84
# 2           2     294     37623        True    -0.5         2.40   6.67
# 3           3     294     37623        True     2.3         2.37   6.98
# 4           4     294     37623        True    -2.7         1.10   5.50
# 5           5     294     37623        True     8.2         2.52   7.84
# 6           6     294     37623        True     0.3         2.15   6.55
# 7           7     294     37623       False     0.0         2.15   6.55
# 8           8     294     37623        True     1.1         2.00   6.50
# 9           9     294     37623        True     4.4         2.30   7.20
# 10         10     294     37623       False     0.0         2.30   7.20
# 11         11     294     37623       False     0.0         2.30   7.20
# ...

# %%
clubes=clubes.rename(columns={'ID': "ClubeID"})
clubes
# Out:
#     ClubeID           Nome Abreviacao           Slug
# 0       262       Flamengo        FLA       Flamengo
# 1       263       Botafogo        BOT       Botafogo
# 2       264    Corinthians        COR    Corinthians
# 3       266     Fluminense        FLU     Fluminense
# 4       275      Palmeiras        PAL      Palmeiras
# 5       276      São Paulo        SAO      Sao-Paulo
# 6       277         Santos        SAN         Santos
# 7       282    Atlético-MG        CAM    Atletico-MG
# 8       283       Cruzeiro        CRU       Cruzeiro
# 9       284         Grêmio        GRE         Gremio
# 10      285  Internacional        INT  Internacional
# 11      287        Vitória        VIT        Vitoria
# 12      292          Sport        SPT          Sport
# 13      293    Atlético-PR        CAP    Atletico-PR
# 14      294       Coritiba        CFC       Coritiba
# 15      303    Ponte Preta        PON    Ponte-Preta
# 16      315    Chapecoense        CHA    Chapecoense
# ...

# %%
#dados da pontuacao dos jogadores separados por equipes
palmeiras= dados[dados.Sigla=="PAL"]
santos= dados[dados.Sigla=="SAN"]
flamengo= dados[dados.Sigla=='FLA' ]
atleticomg= dados[dados.Sigla=='CAM']
botafogo= dados[dados.Sigla=='BOT']
atleticopr= dados[dados.Sigla=='CAP']
corinthians= dados[dados.Sigla=='COR']
pontepreta= dados[dados.Sigla=='PON']
gremio= dados[dados.Sigla=='GRE']
saopaulo= dados[dados.Sigla=='SAO']
chapecoense= dados[dados.Sigla=='CHA']
cruzeiro= dados[dados.Sigla=='CRU']
fluminense= dados[dados.Sigla=='FLU']
sport= dados[dados.Sigla=='SPT']
coritiba= dados[dados.Sigla=='CFC']
vitoria= dados[dados.Sigla=='VIT']
internacional= dados[(dados.Sigla=='INT')]
figueirense= dados[(dados.Sigla=='FIG')]
santacruz= dados[(dados.Sigla=='SCZ')]
america= dados[dados.Sigla=='AME']
america
# Out:
#       Rodada ClubeID  AtletaID  Participou  Pontos  PontosMedia  Preco  \
# 4892       5     327     81794       False     0.0         0.00   5.19
# 4893       0     327     81881       False     0.0         0.00   5.00
# 4894       1     327     81881        True     6.4         6.40   8.38
# 4895       2     327     81881        True    -3.9         1.25   6.63
# 4896       3     327     81881        True    -2.3         0.07   5.44
# 4897       4     327     81881        True     6.4         1.65   7.23
# 4898       5     327     81881        True    -4.3         0.46   4.96
# 4899       6     327     81881        True     8.0         1.72   7.28
# 4900       7     327     81881        True    -6.3         0.57   4.58
# 4901       8     327     81881        True     0.5         0.56   5.39
# 4902       9     327     81881        True     0.7         0.58   5.35
# 4903      10     327     81881        True     4.7         0.99   6.18
# ...

# %%
clubes['FLA', 'BOT', 'COR']
# Out:
#      ID           Nome Abreviacao           Slug
# 0   262       Flamengo        FLA       Flamengo
# 1   263       Botafogo        BOT       Botafogo
# 2   264    Corinthians        COR    Corinthians
# 3   266     Fluminense        FLU     Fluminense
# 4   275      Palmeiras        PAL      Palmeiras
# 5   276      São Paulo        SAO      Sao-Paulo
# 6   277         Santos        SAN         Santos
# 7   282    Atlético-MG        CAM    Atletico-MG
# 8   283       Cruzeiro        CRU       Cruzeiro
# 9   284         Grêmio        GRE         Gremio
# 10  285  Internacional        INT  Internacional
# 11  287        Vitória        VIT        Vitoria
# 12  292          Sport        SPT          Sport
# 13  293    Atlético-PR        CAP    Atletico-PR
# 14  294       Coritiba        CFC       Coritiba
# 15  303    Ponte Preta        PON    Ponte-Preta
# 16  315    Chapecoense        CHA    Chapecoense
# 17  316    Figueirense        FIG    Figueirense
# ...

# %%
FLA38=flamengo[flamengo.Rodada==38]
FLA38=FLA38[FLA38.Participou==True]
FLA38#teste aleatorio para ver se o filtro está certo. todos os jogadores da chapecoense devem estar zerados na rodada 38, uma vez que houve o acidente com o avião da equipe.
# Out:
#        Rodada  Participou  Pontos  PontosMedia  Preco  PrecoVariacao  FS  PE  \
# 23534      38        True   -0.80         2.85  11.84          -0.24   3   6
# 23559      38        True    2.10         1.97   8.10          -0.08   2   1
# 23655      38        True    2.90         3.58  11.02          -0.45   2   2
# 23694      38        True    2.60         3.44  11.01          -0.08   3   2
# 23831      38        True    2.10         5.53  19.55          -2.78   1   2
# 24022      38        True   -5.00         2.57   7.58          -0.87   0   0
# 24076      38        True   12.00         4.65  10.96           1.23   0   0
# 24112      38        True    2.29         4.32  13.77          -0.92   0   0
# 24151      38        True    2.30         4.15   7.95          -1.03   1   2
# 24513      38        True    3.60         4.09   8.24          -0.25   0   3
# 24587      38        True    1.30         2.34   4.65          -0.84   1   3
# ...

# %%
atleticomg[atleticomg.Rodada==38] #atleticomg tb zerado
# Out:
#        Rodada  Participou  Pontos  PontosMedia  Preco  PrecoVariacao  FS  PE  \
# 14071      38       False     0.0         4.16  18.58            0.0   0   0
# 14110      38       False     0.0         1.04   7.34            0.0   0   0
# 14149      38       False     0.0         3.01  10.03            0.0   0   0
# 14181      38       False     0.0        -1.50   1.26            0.0   0   0
# 14206      38       False     0.0         2.72   8.61            0.0   0   0
# 14208      38       False     0.0         0.00   1.00            0.0   0   0
# 14247      38       False     0.0         4.91  22.11            0.0   0   0
# 14286      38       False     0.0         2.24   6.86            0.0   0   0
# 14325      38       False     0.0         2.35   6.09            0.0   0   0
# 14361      38       False     0.0        -0.37   0.77            0.0   0   0
# 14397      38       False     0.0         0.00   1.00            0.0   0   0
# ...

# %% [markdown]
# # objetivo do trabalho: fazer uma seleção do brasileirão com base na média dos pontos dos jogadores
# ### Técnica exemplo: desempenho do Paolo Guerrero

# %%
a=atletas[atletas.Apelido=="Paolo Guerrero"]
a
# Out:
#      AtletaID         Apelido  ClubeID  PosicaoID
# 305     75295  Paolo Guerrero      262          5

# %%
AtletaID = 75295 # Paolo Guerrero
dados_atleta = dados[dados.AtletaID == AtletaID]
dados_atleta
x =dados_atleta['Rodada']
y = dados_atleta['Pontos']
z=dados_atleta['Preco']
#plt.plot(x,y)
plt.plot(x,z) 
plt.title("Variação do **preço** de Paolo Guerrero no CartolaFC")

# %%
plt.plot(x,y) 
plt.title("Variação da **pontuação**  de Paolo Guerrero no CartolaFC")

# %%
dados_atleta.Preco.describe() # media de preco do guerrero guerrero
#fazer isso com todos os jogadores
# Out:
# count    39.000000
# mean      7.868462
# std       2.466004
# min       5.760000
# 25%       6.740000
# 50%       7.300000
# 75%       7.885000
# max      21.000000
# Name: Preco, dtype: float64

# %%
dados_atleta.Pontos.describe() # media de preco do  guerrero
# Out:
# count    39.000000
# mean      2.233333
# std       4.701866
# min      -4.100000
# 25%       0.000000
# 50%       0.000000
# 75%       2.650000
# max      15.400000
# Name: Pontos, dtype: float64

# %%
# objetivo do trabalho: fazer uma seleção do brasileirão com base na média dos pontos dos jogadores

# %%
x =flamengo['Rodada']
y = flamengo['Pontos']

# Set the size of the plot
plt.figure(figsize=(14,7))

# Create a colormap
colormap = np.array(['red', 'lime', 'black'])

# Plot Sepal
#plt.subplot(1, 2, 1)
#plt.scatter(flamengo.Rodada, flamengo.Pontos,  s=40)
#plt.title('FLA')

plt.subplot(1, 2, 1)
plt.scatter(palmeiras.Rodada, palmeiras.Pontos,  s=40)
plt.title('PAL')
plt.axis([0, 39, -5, 25])

plt.subplot(1,2,2)
plt.scatter(america.Rodada, america.Pontos, s=40)
plt.title('AME')
# Set the size of the plot
plt.axis([0, 39, -5, 25])

plt.figure(figsize=(14,7))

'''
# Create a colormap
colormap = np.array(['red', 'lime', 'black'])
 
# Plot Sepal
plt.subplot(1, 2, 1)
plt.scatter(x.Sepal_Length, x.Sepal_Width, c=colormap[y.Targets], s=40)
plt.title('Sepal')

plt.subplot(1, 2, 2)
plt.scatter(x.Petal_Length, x.Petal_Width, c=colormap[y.Targets], s=40)
plt.title('Petal')
'''
# Out:
# "\n# Create a colormap\ncolormap = np.array(['red', 'lime', 'black'])\n \n# Plot Sepal\nplt.subplot(1, 2, 1)\nplt.scatter(x.Sepal_Length, x.Sepal_Width, c=colormap[y.Targets], s=40)\nplt.title('Sepal')\n\nplt.subplot(1, 2, 2)\nplt.scatter(x.Petal_Length, x.Petal_Width, c=colormap[y.Targets], s=40)\nplt.title('Petal')\n"

# %%
rodada1fla=flamengo[flamengo.Rodada==1]# & (flamengo.Participou==True)]
#rodada1fla=rodada1[rodada1.clubeID==]
rodada1fla=rodada1fla.Pontos.sum()

# %%
rodada1ame=america[(america.Rodada==1)]# & (america.Participou==False)]
rodada1ame=rodada1ame.Pontos.sum()

# %%
rodada1fla
# Out:
# 79.75

# %%
rodada1ame
# Out:
# 37.199999999999996

# %%
goleiro=dados[dados.PosicaoID==1]
goleiro.Pontos.max()
# Out:
# 21.0

# %%
posicoes
# Out:
#    ID      Nome Abreviacao
# 0   1   Goleiro        GOL
# 1   2   Lateral        LAT
# 2   3  Zagueiro        ZAG
# 3   4      Meia        MEI
# 4   5  Atacante        ATA
# 5   6   Técnico        TEC

# %%
dados.PosicaoID
# Out:
# 0        3
# 1        3
# 2        3
# 3        3
# 4        3
# 5        3
# 6        3
# 7        3
# 8        3
# 9        3
# 10       3
# 11       3
# 12       3
# 13       4
# 14       4
# 15       4
# 16       4
# 17       4
# 18       4
# 19       4
# 20       4
# 21       4
# 22       4
# 23       4
# 24       4
# 25       4
# 26       4
# 27       4
# 28       4
# 29       4
#         ..
# 31131    4
# 31132    4
# 31133    4
# 31134    4
# 31135    4
# 31136    4
# 31137    4
# 31138    4
# 31139    4
# 31140    4
# 31141    4
# 31142    4
# 31143    4
# 31144    4
# 31145    5
# 31146    5
# 31147    5
# 31148    5
# 31149    5
# 31150    5
# 31151    5
# 31152    5
# 31153    5
# 31154    5
# 31155    5
# 31156    1
# 31157    1
# 31158    1
# 31159    1
# 31160    3
# Name: PosicaoID, Length: 31161, dtype: int64

# %%
flamengo.Pontos.describe() # media de preco do guerrero guerrero
# Out:
# count    1499.000000
# mean        1.319820
# std         2.988713
# min        -6.300000
# 25%         0.000000
# 50%         0.000000
# 75%         1.300000
# max        18.500000
# Name: Pontos, dtype: float64

# %%
palmeiras.Pontos.describe() # media de preco do guerrero guerrero
# Out:
# count    1468.000000
# mean        1.143474
# std         2.919486
# min        -8.600000
# 25%         0.000000
# 50%         0.000000
# 75%         0.700000
# max        24.400000
# Name: Pontos, dtype: float64

# %%
america.Pontos.describe() # media de preco do guerrero guerrero
# Out:
# count    1435.000000
# mean        0.645059
# std         2.158962
# min        -6.300000
# 25%         0.000000
# 50%         0.000000
# 75%         0.100000
# max        14.000000
# Name: Pontos, dtype: float64

# %%
dados
# Out:
#        Rodada ClubeID  AtletaID  Participou  Pontos  PontosMedia  Preco  \
# 0           0     294     37623       False     0.0         0.00   4.00
# 1           1     294     37623        True     5.3         5.30   6.84
# 2           2     294     37623        True    -0.5         2.40   6.67
# 3           3     294     37623        True     2.3         2.37   6.98
# 4           4     294     37623        True    -2.7         1.10   5.50
# 5           5     294     37623        True     8.2         2.52   7.84
# 6           6     294     37623        True     0.3         2.15   6.55
# 7           7     294     37623       False     0.0         2.15   6.55
# 8           8     294     37623        True     1.1         2.00   6.50
# 9           9     294     37623        True     4.4         2.30   7.20
# 10         10     294     37623       False     0.0         2.30   7.20
# 11         11     294     37623       False     0.0         2.30   7.20
# ...

# %%
atletas.head()
# Out:
#    AtletaID         Apelido  ClubeID  PosicaoID
# 0     37623  Rafael Marques      294          3
# 1     72382      Marquinhos      277          5
# 2     95830    Emerson Cris      315          6
# 3     81794  Cláudio Prates      327          6
# 4     37837        Cristian      303          4

# %%
atletas=atletas.rename(columns={'ID': "AtletaID"})

dados= pd.merge(dados,atletas[['AtletaID', 'PosicaoID', 'Apelido']], on='AtletaID')
#result = pd.merge(dados,atletas[['AtletaID', 'Apelido']], on='AtletaID')

result
lateral=result[result.PosicaoID==2]
lateral.Pontos.max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-b52ee12b4859> in <module>()
#       4 #result = pd.merge(dados,atletas[['AtletaID', 'Apelido']], on='AtletaID')
#       5
# ----> 6 result
#       7 lateral=result[result.PosicaoID==2]
#       8 lateral.Pontos.max()
#
# NameError: name 'result' is not defined

# %%
atletas=atletas.rename(columns={'ID': "AtletaID"})

#df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'}, inplace=True)#df = df.rename(columns={'oldName1': 'newName1', 'oldName2': 'newName2'})

# %%
atletas
# Out:
#       AtletaID            Apelido  ClubeID  PosicaoID
# 0        37623     Rafael Marques      294          3
# 1        72382         Marquinhos      277          5
# 2        95830       Emerson Cris      315          6
# 3        81794     Cláudio Prates      327          6
# 4        37837           Cristian      303          4
# 5        38062             Lugano      276          3
# 6        38109          Jefferson      263          1
# 7        38139               Bobô      284          5
# 8        38162               Fred      282          5
# 9        38061           Edcarlos      282          3
# 10       38100             Durval      292          3
# 11       38140     Fernando Prass      275          1
# 12       93733       Ítalo Borges      344          5
# 13       73580             Falcão      285          6
# 14       94336             Mateus      266          4
# 15       37792             Edinho      294          4
# ...
